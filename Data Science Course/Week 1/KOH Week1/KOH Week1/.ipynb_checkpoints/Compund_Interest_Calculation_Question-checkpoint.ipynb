# %% [markdown]
# <h2>Compund Interest calculator</h2>
#
#
#
# Screen Shot 2018-04-01 at 1.27.17 AM![image.png](attachment:image.png)

# %% [markdown]
# <p>The above illustrates the formula to calculate an individuals overall savings while taking in account the compound interest. Using the variables & data already provided, calculate the individual's total amount of money he will have and print out the answer. In order ways, calculate variable A and print it out!</p>

# %%
#Below are the data provided, you cannot directly change the value of the data below. You can however, perform actions
#such as type conversion of necessary (eg. str())

P = 10000
r = '0.08'
n = 1
t = 15

#Type your code below
r=float(r)
A=P(1+r/n)**(n*t)
print(A)
# Out:
#   File "<ipython-input-6-7164bf6396e1>", line 11
#     (float)A=P(1+r/n)**(n*t)
#            ^
# SyntaxError: invalid syntax
