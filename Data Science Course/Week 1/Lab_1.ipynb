# %% [markdown]
# <h2> Question 2: </h2>
# Print the type of the following variables:
#
# Channel_Title = "20th Century Fox" <br>
# Title = 'Pirates of the Caribbean' <br>
# Likes = 23009 <br>
# Comments = 2000 <br>
# Rating = 4.7 <br>
# Popular = True

# %%
#Write your answer in comments beside the variables. For example
example = "example" #String type

#Write your answers here
print("Channel_Title = \"20th Century Fox\"") 
print("Title = 'Pirates of the Caribbean'") 
print("Likes = 23009") 
print("Comments = 2000") 
print("Rating = 4.7") 
print("Popular = True")
# Out:
# Channel_Title = "20th Century Fox"
# Title = 'Pirates of the Caribbean'
# Likes = 23009
# Comments = 2000
# Rating = 4.7
# Popular = True

# %% [markdown]
# <h2> Question 3: </h2>
# Write the variable type of the following variables beside the variables in the cell below:
#
# ![image.png](attachment:image.png)

# %%
#Write your answer in comments beside the variables. For example
example = "example" #String type

#write your answer below
Likes = '100' #String 
Likes = int(Likes) #integer
Channel_Title = 1.7 #float
Channel = "Lord of the Rings" #String

# %% [markdown]
# <h2> Question 4: </h2>
# One of the typical metrics for measuring the engagement of videos is through likes per view. Given the following data, write a program to measure the likes/view of "Lord of the Rings"
#
# Title = "Lord of the Rings" <br>
# Number_of_likes = "30" <br>
# Number_of_views = 30218

# %%
Title = "Lord of the Rings" 
Number_of_likes = "30" 
Number_of_views = 30218
Number_of_likes=int(Number_of_likes)

total=Number_of_likes/Number_of_views
print(Title+" = "+str(total))
# Out:
# Lord of the Rings = 0.0009927857568336753

# %% [markdown]
# <h2>Question 5:</h2>
# One of the title of the video contains some special characters. Make use of string indexing to remove it
#
# Title = "Lord of the*&@#(* Ring" <br>
#
# Your output should be: "Lord of the Ring"

# %%
Title = "Lord of the&@#( Ring" 

print("\""+Title[0:11]+" "+Title[-4:]+"\"")
# Out:
# "Lord of the Ring"

# %% [markdown]
# <h2>Question 6:</h2>
# One of the title of the video is reversed. Make use of string indexing to reverse it back.
#
# Title = "rettop yarrh"
#
# Your output should be: “Harry Potter”

# %%
Title = "rettop yrrah"

Title=Title[::-1]
print("\""+ Title.title()+"\"")
# Out:
# "Harry Potter"

# %% [markdown]
# <h2> Question 7:</h2>
# A newbie to programming wrote the following piece of code to calculate the engagement of a certain video. However, her codes were met with syntax, logic bugs and exceptions. Debug the following code for her:

# %%
#debug the following
#Number_of_likes = "35000"
#Number_of_views = 1000000
#engagement =Number_of_likes/Number_Of_views
Number_of_likes="35000"
Number_of_views=1000000
Number_of_likes=int(Number_of_likes)
engagement=Number_of_likes/Number_of_views
print("The engagement rate is: " + str(engagement))
# Out:
# The engagement rate is: 0.035

# %% [markdown]
# <h2>Question 8:</h2>
# Another newbie to programming wrote the following piece of code to calculate the engagement of a video. However, her codes were met with syntax, logic bugs and exceptions. Debug the following code for her:

# %%
#Another way to calculate engagement is the number of comments per view

#debug the following
Num_of_comments = 2389
Num_of_views = 9233000

Engagement_lvl = Num_of_views / Num_of_comments

print('The engagement rate is: ' + str(Engagement_lvl))
# Out:
# The engagement rate is: 3864.796986186689

# %% [markdown]
# <h2>Question 9:</h2>
# Watch the following short videos in preparation for the next lesson:
#
# Strings, Lists, Tuples, and Dictionaries: https://www.youtube.com/watch?v=19EfbO5D_8s <br>
# Conditionals, If, Else, Elif: https://www.youtube.com/watch?v=mQrci1kAwh4
